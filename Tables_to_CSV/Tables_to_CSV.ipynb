# %% [markdown]
# # Description of the project

# %% [markdown]
# * This project involves a script to import tables from scientific papers, thesis or any .pdf file.
# * I used my [M.Sc. Thesis article](https://www.sciencedirect.com/science/article/abs/pii/S0024493720301900) and [Sciuba's 2020 PhD thesis](https://corpus.ulaval.ca/jspui/browse?type=author&order=ASC&rpp=20&authority=24f39a93-12d1-414c-847b-74b0ab5a0f2e) for testing and the output results are good enough to automatize a database building process using Python.
# * This script is suited to be used in Google Colab, but it can be adapted to other platforms, such as Jupyter Notebooks and Python IDEs.
# * I wrote this script because I used to type or copy and paste (when possible) every cell from a table when I wanted to build my databases, and now with Python, there is no need for that.
# * In future developments, I will use image recognition to import tables from old scanned thesis and papers.

# %% [markdown]
# ## Read me!

# %% [markdown]
# *   If you are familiar with Python and/or have already used notebook documents, you can skip to the next section.
#
# *   This code is built for you to edit, depending on your goals, but it requires minimum knowledge of running it.
#
# *   I recommend using your Google account (or create one if you don't have one) and install Google Colab (short for Colaboratory). This [link](https://www.youtube.com/watch?v=xoo4mTujM1U) is a short Youtube video teaching you how to do it.
#
# *   The link you received is from Github, a platform that allows you to host your code on the internet and save different versions of it, so you can always have version control and track your progress, mistakes, etc. Github is also a social media for programmers.
#
# *   The link you received will look like the following image. If you installed Google Colab, please access this link: https://colab.research.google.com/drive/1AkqYcounSwgzKXRytGUoO3crnYwxNnM9?usp=sharing

# %% [markdown]
# ![Screen Shot 2021-03-11 at 22.31.25.png](data:image/png;base64,...)

# %% [markdown]
# *   When you open the link, a Google Colab tab in your browser will appear, click on *File > Save a copy on Drive*. A new browser tab will open. This new tab will be your copy of my notebook. **Please, only edit this copy; you can save it, change it and keep it**.
#
# *   Notebook environments in Python allow you to use code cells and text cells. In this way, it is easier and prettier to explain your code. Code cells are indicated by brackets **[   ]**, code comments and instructions are contained inside the code cells and are noted by **#**.
#
# *   It is important to feed Google Colab with the articles or thesis you want to extract the information. To do this, click on the folder in the bar on the left, drag the files into the white space and drop them. These files will be uploaded in a temporary virtual machine, if you stay offline for too long, the machine will disconnect, and you will have to do this process again.
#
# *   To run the code, you will have to follow the order of the cell codes from top to bottom because you need to install a series of packages and libraries. This initial installing setup is indicated in the code in the next section. Just run each cell by clicking on them and pressing *Shift + Enter* or pressing the "play" button on its left. It is important to finalize the processing time of one cell before moving to the next one.
#
# *   After installing all the required packages, follow the instructions contained in the comments of the code cells.

# %% [markdown]
# ## Source code

# %% [markdown]
# ### This is the setup section, install everything and follow the code cell's order

# %% [markdown]
# This code is dependent on Camelot, a table recognizing library on Python. It is essential to install it correctly.
#
# Documentation for Camelot: https://buildmedia.readthedocs.org/media/pdf/camelot-py/latest/camelot-py.pdf

# %%
# Install ghostscript (needed to run Camelot)

! apt install python3-tk ghostscript

# %%
# Import tkinter (needed to run Camelot)

import tkinter

# %%
# Check if ghostscript is installed correctly, if not, contact me at 
# eduardo.valentin-dos-santos.1@ulaval.ca

# !gs -version
# Out:
# GPL Ghostscript 9.26 (2018-11-20)
# Copyright (C) 2018 Artifex Software, Inc.  All rights reserved.

# %%
# Install Camelot through pip

# !pip install camelot-py[cv]

# %%
# Import Camelot

import camelot

# %% [markdown]
# ### This is the source code, follow the comments to adapt for your case

# %% [markdown]
# #### Example 1: An article (Lithos)

# %% [markdown]
# * I used my [M.Sc. Thesis article](https://www.sciencedirect.com/science/article/abs/pii/S0024493720301900) for testing.
#
# * The .csv files generated from this code are all in the Github folder containing this notebook, but I will share some sample output images at the end of this example.

# %%
# The path of the file you want to scan. You can discover the path of a file in Google Colab
# by clicking on the folder in the left sidebar and right-clicking in your .pdf file, then
# selecting "Copy path". Once you have the path, paste it in the variable file_path, but 
# between quotes.

file_path = '/content/Valentin_etal_2020.pdf'

# %%
# This function reads the pdf looking for tables; flavor='lattice' is better suited for tables 
# with great spacing between rows and columns. It doesn't work in many cases, but it is worth
# trying. The pages notation can be used to specify the .pdf page you want to scan; I chose in
# this example "1-end" to scan the entire document.

tables = camelot.read_pdf(file_path, pages = "1-end", flavor='lattice')

# %%
# I'm calling the previously created tables variable to show how many tables the read_pdf function 
# recognized. It recognized eleven tables.

tables
# Out:
# <TableList n=11>

# %%
# I've created a loop to show me precisely what tables are contained in the tables variable. Python 
# starts counting from 0 to the specified number. Since our last function recognized eleven table 
# objects, I have to loop until the 10th element. As I said earlier, the flavor='lattice' doesn't 
# work in many cases, so this loop's output is nonsense.

for i in range(10):
  print(tables[i].df)
# Out:
#   0 1
# 0
# 1
#   0 1 2
# 0
# 1
# 2
#   0 1
# 0
# 1
#   0 1 2
# 0
# 1
#   0 1 2
# 0
# 1
#   0 1 2
# 0
# 1
#   0 1 2
# 0
# 1
#   0 1 2
# 0
# 1
#   0 1 2
# 0
# 1
#   0
# 0

# %%
# Since the last attempt wasn't successful, I will call the read_pdf function again, but with 
# flavor='stream', another option available from Camelot's documentation. This mode recognizes more 
# things like a table object, but its accuracy is a lot worse, so additional work must be done to 
# filter and organize the final output. The result of this function is assigned to the tables2
# variable.

tables2 = camelot.read_pdf(file_path, pages='1-end', flavor='stream')

# %%
# I'm calling the previously created tables2 variable to show how many tables the read_pdf function 
# recognized. It recognized twenty-four tables.

tables2
# Out:
# <TableList n=25>

# %%
# I've created a loop to show me precisely what tables are contained in the tables variable. Python 
# starts counting from 0 to the specified number. Since our last function recognized twenty-four 
# table objects, I have to loop until the 23th element. In this case, the function recognized too 
# many things. The article's columns were recognized as tables, so I will use a logic condition to 
# filter what is text and tables in the next cell.

for i in range (23):
  print(tables2[i].df)
# Out:
#                                                     0                                                  1
# 0                                                      j o u r n a l h o m e p a g e : w w w . e l s ...
# 1                                    Research Article
# 2   Monte Santo suite, an example of Ediacaran-Cam...
# 3   rocks in the Araguaia Belt, Central Brazil. Im...
# 4                                  Gondwana evolution
# 5   Eduardo Valentin ⁎, Nilson F. Botelho, Elton L...
# 6   Instituto de Geociências, Universidade de Bras...
# 7                              a r t i c l e\ni n f o                                    a b s t r a c t
# 8                                    Article history:  Deformed alkaline rocks and carbonatites (DARC...
# 9                              Received 14 March 2019
# 10                                                     perienced two separate events of rifting and c...
# 11             Received in revised form 24 April 2020
# 12                                                     synkinematically emplaced along major structur...
# 13                             Accepted 25 April 2020
# 14                                                     logic event. The Monte Santo Suite consists of...
# 15                        Available online 1 May 2020
# 16                                                     Santo) that crop out in the Araguaia Belt and ...
# 17                                                     this study, we use the chemistry, mineralogy a...
# 18                                          Keywords:
# 19                                                     the relations between its emplacement, the Bra...
# 20                                  Nepheline Syenite
# 21                                  Monte Santo Suite  Gondwana. The intrusions are predominantly nep...
# 22                            Deformed Alkaline Rocks  composition from omphacite to aegirine-augite ...
# 23                                      Araguaia Belt  istics. Biotite varies from phlogopite to side...
# 24                                 Ediacaran-cambrian  neoformed trends. Amphibole varies from hastin...
# 25                             Brasiliano/Pan-African
# 26                                                     and low-temperature varieties. The REE and tra...
# 27                                                     bulk content variations, positive anomalies fo...
# 28                                                     multielement diagrams, The Zr/Hf ratios for al...
# 29                                                     range from −10.1 to −3.0. Trace element and is...
# 30                                                     fractional crystallization, crustal contaminat...
# 31                                                     The Monte Santo Suite crystallization age is d...
# 32                                                     synkinematically with shearing along major reg...
# 33                                                     suite is an example of alkaline rocks generate...
# 34                                                                                             Gondwana.
# 35                                                             © 2020 Elsevier B.V. All rights reserved.
#                                                     0                                                  1
# 0                                     1. Introduction  Nb\nand\nTa\nanomalies,\nand\nis\ngenetically\...
# 1                                                                                             magmatism.
# 2   Alkaline rocks and carbonatites occur in almos...  Several mechanisms to generate nepheline syeni...
# 3   tonic environment and are distributed from the...  posed, including the fractional crystallizatio...
# 4   (Haissen et al., 2017). The most classic examp...  sented by alkaline basalts, nephelinites, basa...
# 5   are associated with intracontinental rifts (e....  rocks or by low fractions of partial melts of ...
# 6   Province) (Bailey, 1992). They are also typica...  rocks (Leat et al., 1988; Price et al., 1985; ...
# 7   magmatism, whether continental or oceanic (e.g...  Burke et al. (2003) observed that most African...
# 8   Monteregian Hills Province, Canary Islands, Ha...  Rocks and Carbonatites (DARCs) are concentrate...
# 9   magmatism associated with subduction or contin...  zones and suggested that they might represent ...
# 10  common than that associated with intracontinen...  well-deﬁned parts of the Wilson cycle. Based o...
# 11  tinctively related to potassium-rich magmas, u...  imity between DARCs and younger Alkaline Rocks...
# 12                                                     (ARCs), these authors further suggested that A...
# 13                                                     the melting of an ancient DARC source if these...
# 14                                                     reached adequate depths in the lithospheric ma...
# 15                           ⁎\nCorresponding author.
# 16  E-mail addresses: eduardovalentindossantos@gma...  Other mechanisms for the generation of DARCs h...
# 17  nilsonfb@unb.br (N.F. Botelho), elton@unb.br (...  such as rifting associated with a punctual int...
#                                                     0
# 0   2\nE. Valentin et al. / Lithos 366–367 (2020) ...
# 1   evaporation method (Gorayeb et al., 2004). The...
# 2   was considered an Archean greenstone belt meta...
# 3   sequence,\nbut\nSouza\n(2018)\nreclassiﬁed\nth...
# 4   Neoproterozoic dismembered ophiolite.\npothesi...
# ..                                                ...
# 62  were an acceleration voltage of 15 kV and a be...
# 63  counting times at peak and background for all ...
# 64  respectively.\npergroup rocks. The Quatipuru o...
# 65  The calibration procedure was carried out usin...
# 66  ral minerals as standards: albite (NaKα), pyro...
#
# [67 rows x 1 columns]
#                                                     0                                                  1
# 0   Fig. 1. A) Regional geological map of the Arag...
# 1   illustrates the geological background near the...
# 2   Massif, with fenite zones, sampling locations ...
# 3   and foliation directions. Modiﬁed from Alvaren...
# 4   microcline (SiKα, AlKα, KKα), andradite (FeKα)...  cycle of analyzing a blank, a GJ-1 reference z...
# 5   atite (CaKα), vanadinite (ClKα, VKα),\ntopaz\n...  Often, between the analyzed samples, an intern...
# 6   (CrKα). ZAF correction procedure was used to a...  of the 91,500 reference zircon (Wiedenbeck et ...
# 7   The most representative analyses are presented...  to evaluate the quality and reproducibility of...
# 8   In situ U-Pb isotopic analyses were carried ou...  about the applied methods can be found in Bühn...
# 9   using a Thermo Finnigan Neptune multicollector...          analyses are presented in the Appendix 2.
# 10  plasma mass spectrometer coupled with a New Wa...  Data\nreduction was performed by the Microsoft...
# 11  Nd:YAG solid-state laser with an output wavele...  Chronus (Oliveira, 2015), where raw data were ...
# 12  Geochronology Laboratory of the University of ...  background signals, common Pb, elemental fract...
# 13  Zircon crystals were individually hand-picked ...  mental drift. The corrected data were plotted ...
# 14  ameter plastic rings ﬁlled with two-compound e...                      using ISOPLOT (Ludwig, 2003).
# 15  zircon\ngrain\nwas\nimaged\nfor\nback-scattere...  Whole-rock Sm-Nd analyses were carried out\nin...
# 16                       cathodoluminescence by EPMA.  sector ﬁeld Thermo Fisher Scientiﬁc Triton Plu...
# 17  The utilized ablation spots were 30 or 40 μm, ...  mass spectrometer at the Geochronology Laborat...
# 18  10 Hz, and an intensity of 2.64–2.77 J/cm2. Th...  of Brasília. Rock powders were mixed with a 14...
# 19  was carried by a gas ﬂux of helium (0.4 L/min)...  tion and digested by acid attacks,\nfollowed b...
# 20  A standard sample bracketing technique was app...  aration of Sm and Nd from the other rare earth...
#                                                     0
# 0   4\nE. Valentin et al. / Lithos 366–367 (2020) ...
# 1   4.3. Nepheline monzosyenite\nthe applied analy...
# 2                                             (2000).
# 3   The nepheline monzosyenite occurs in the lowla...
# 4   evations of the Estrela Massif. They are mediu...
# ..                                                ...
# 90  marginal\nrecrystallization (Fig. 2G), charact...
# 91  grained, homogeneous and granoblastic subsolid...
# 92  The maﬁc minerals generally occur as oriented ...
# 93  late texture, where amphibole and less commonl...
# 94  intercumulus minerals.\nposition in all lithol...
#
# [95 rows x 1 columns]
#                                                     0                                                  1
# 0   Fig. 2. Field aspects of the rocks of the Mont...
# 1   D) Igneous foliation with irregular banding an...
# 2   Massif. F) Microscopic foliation with ﬁne-grai...
# 3   crystals in a nepheline syenite sample (EVES50...
# 4   Massif. I) Well-preserved igneous hypidiomorph...
# 5   Monte Santo Massif, with preserved igneous tex...
# 6   granular texture in an alkali feldspar syenite...
# 7                                      5.2. Nepheline                                       5.3. Biotite
# 8   Nepheline structural formulae were calculated ...  Biotite is the most abundant maﬁc mineral in t...
# 9   gen; additionally, the Na, K, Ca and appropria...  feldspar syenite of the Monte Santo Massif and...
# 10  ions were calculated as the endmembers nepheli...  Estrela Massif.\nIt occurs as ﬂakes and rarely...
# 11  kalsilite (Ks – KAlSiO4) and anorthite (An – □...  poikilitic crystals (Fig. 2F) or radial aggreg...
# 12  Si was calculated as quartz (Qz – □Si2O4). The...  association with other maﬁc minerals,\nsuch as...
# 13  were recalculated to 100%, as proposed in Hami...                                         magnetite.
# 14  (1960). The normalized endmember percentages w...  Biotite\ncompositions\nare\nclassiﬁed\nfollowi...
# 15  ternary diagram of the NaAlSiO4-KAlSiO4-Si2O4 ...  Tischendorf et al. (2007) as the varieties ann...
# 16  using the isotherms deﬁned by Hamilton and Mac...  phlogopite (Fig. 3B). Structural formulas were...
# 17  Hamilton (1961) (Fig. 3A). The Barth plane, wh...  ygen atoms, considering all the iron as divalent.
# 18  nepheline compositions (Dollase and Thomas, 19...  In the Monte Santo Massif, biotite is widespre...
# 19                  trol the quality of the analyses.  kali feldspar syenite and rarely occurs in the...
# 20  Nepheline occurs in different textural varieti...  position is annite and its maximum TiO2 conten...
# 21  cluding coarse (5–6 mm) subhedral crystals, me...  In the Estrela Massif, biotite occurs in all l...
# 22  crystals and crystals with well-developed face...  phlogopite to siderophyllite to annite. Phlogo...
# 23  anhedral crystals (1–1.5 mm) and ﬁne-grained r...  line monzodiorite, siderophyllite in the nephe...
# 24  (0.1–0.2 mm) within other minerals, usually fe...  neoformed grains, with radial texture in nephe...
# 25  There are signiﬁcant differences between the c...  in nepheline syenite and nepheline alkali feld...
# 26  within the syenites of the Monte Santo Massif ...  siderophyllite and annite maximum TiO2 content...
# 27  Massif. In the Monte Santo Massif, nepheline c...  and 3.82%, respectively. There is a tendency f...
# 28  in the range of Ne68.6–79.5Ks19.7–23.3Qz0.0–8....  of biotite to contain the highest amounts of T...
# 29  ture is mostly below 500 °C, with only one poi...                      grains contain lower amounts.
# 30                                          isotherm.
# 31  In\nthe\nEstrela Massif\nsyenites,\nnepheline\...
# 32  constrained in the Ne71.2–80.9Ks16.1–21.1Qz0.1...                                     5.4. Amphibole
# 33  perature is widely spread, with their higher t...
# 34  between the 775 °C and 1068 °C isotherms, well...  Amphibole is the most common mineral in the ne...
# 35  (an intersection of the Barth plane within the...  the Monte Santo Massif and a usual maﬁc minera...
# 36  projected from the An corner). In the nephelin...  It occurs as interstitial (0.8–1 mm) crystals ...
# 37  tions\nare\ninterval,\nconstrained in the Ne75...  (2–5 mm) with inclusions of nepheline and feld...
# 38  representing even higher temperatures than tho...                                         are zoned.
#                                                     0                                                  1
# 0   Fig. 3. Compositions of Monte Santo Suite neph...
# 1   (1960) and Hamilton (1961). Morozewicz and Bue...
# 2   FeAl (VIFetotal + Mn + Ti – Al) diagram of Tis...
# 3   jadeite - aegirine ternary diagram of Morimoto...
# 4   The cation allocation, estimation of ferric ir...  Clinopyroxene is a rare mineral phase within t...
# 5             in accordance with Leake et al. (1997).  and occurs as ﬁne rounded crystals or as aggre...
# 6   In the Monte Santo Suite,\nthe amphiboles span...                  crystals. Both types lack zoning.
# 7   range from calcic to sodic-calcic. In the Mont...  In the Monte Santo Massif, aegirine occurs in ...
# 8   amphibole phase is the sodic-calcic species ta...  while in the Estrela Massif, aegirine-augite i...
# 9   sif, taramite is present in all the syenites a...  nepheline syenite, and omphacite occurs in the...
# 10  and hastingsite is the species in the nephelin...                                         (Fig. 3D).
# 11                                 5.5. Clinopyroxene                                    6. Geochemistry
# 12  The nomenclature and cation allocation are in ...  The\nlithotypes\nof\nthe Monte\nSanto\nSuite\n...
# 13                            Morimoto et al. (1988).  metaluminous to peraluminous silica-undersatur...
#                                                    0   ...      14
# 0                                             Table 1  ...
# 1   Whole-rock major element analyses of the Monte...  ...
# 2        eline syenite, AFS- Alkali feldspar syenite.  ...
# 3                                           Rock Type  ...     AFS
# 4                                              Massif  ...     MSM
# 5                                          Sample no.  ...   MS398
# 6                                Major elements (wt%)  ...
# 7                                                SiO2  ...   58.15
# 8                                                TiO2  ...   0.083
# 9                                               Al2O3  ...   21.21
# 10                                                  t  ...
# 11                                              Fe2O3  ...    4.73
# 12                                                MnO  ...   0.121
# 13                                                MgO  ...    0.08
# 14                                                CaO  ...    0.55
# 15                                               Na2O  ...    7.18
# 16                                                K2O  ...    6.09
# 17                                               P2O5  ...    0.02
# 18                                                LOI  ...    1.18
# 19                                              Total  ...   99.39
# 20                                                  C  ...    n.a.
# 21                                                  S  ...    n.a.
# 22                                                     ...
# 23                                         Orthoclase  ...    36.0
# 24                                             Albite  ...    39.1
# 25                                          Anorthite  ...     2.6
# 26                                          Nepheline  ...    11.7
# 27                                            Leucite  ...     0.0
# 28                                          Rock Type  ...     AFS
# 29                                             Massif  ...      EM
# 30                                         Sample no.  ...  EVES01
# 31                               Major elements (wt%)  ...
# 32                                               SiO2  ...    61.7
# 33                                               TiO2  ...    0.27
# 34                                              Al2O3  ...    18.9
# 35                                                  t  ...
# 36                                              Fe2O3  ...    4.52
# 37                                                MnO  ...    0.13
# 38                                                MgO  ...    0.32
# 39                                                CaO  ...    0.71
# 40                                               Na2O  ...    7.18
# 41                                                K2O  ...    5.15
# 42                                               P2O5  ...    0.11
# 43                                                LOI  ...    0.61
# 44                                              Total  ...    99.6
# 45                                                  C  ...    0.05
# 46                                                  S  ...    0.01
# 47                                                     ...
# 48                                         Orthoclase  ...    30.4
# 49                                             Albite  ...    54.5
# 50                                          Anorthite  ...     2.8
# 51                                          Nepheline  ...     3.4
# 52                                            Leucite  ...     0.0
#
# [53 rows x 15 columns]
#                                                     0                                                  1
# 0   Frost, 2008), with sodic afﬁnities in terms of...  Eu* = 0.94) to well-developed (Eu/Eu* = 0.47)....
# 1   reﬂecting the modal predominance of albite and...  has La/SmN and Gd/LuN ratios of 12.34 and 0.8,...
# 2   In the major element variation diagrams, SiO2 ...    developed Eu anomalies (Eu/Eu* = 0.53 to 0.19).
# 3   fractionation index because it presents the hi...  The nepheline syenite of the Estrela Massif ha...
# 4   the evaluated samples (45.2–62.7 wt%, Table 1)...  Gd/LuN ratios of 10.86 and 0.49, respectively,...
# 5   trends of TiO2, CaO, and MgO and concave trend...  anomalies (Eu/Eu* = 0.38 to 0.18). The availab...
# 6           with increasing differentiation (Fig. 5).  feldspar syenite, nepheline monzosyenite and n...
# 7   The rare earth elements (REEs) present concent...  indicate less pronounced LREE enrichment (La/S...
# 8   10 to 296 times and 16 to 1450 times the chond...  2,94, respectively), almost ﬂat or decreasing ...
# 9   num in the Monte Santo Massif and Estrela Mass...  0.83, 1,71 and 1.51,\nrespectively)\nand,\nexc...
# 10                                          Table 2).  monzodiorite, pronounced Eu anomalies (Eu/Eu* ...
# 11  The average La/SmN and Gd/LuN of the nepheline...  Ascending HREE patterns are commonly observed ...
# 12  nite and alkali feldspar syenite of the Monte ...                            depicted by Gd/LuN b 1.
# 13  1,21, respectively, indicating fractionated LR...  The syenites of the Monte Santo Massif show we...
# 14  ﬂat HREE pattern. Eu negative anomalies vary f...  ative anomalies for Ba, Sr, P and Ti and posit...
#                                                     0                                                  1
# 0   Fig. 4. A) Na2O versus K2O in weight percent. ...
# 1   kaliophilite) versus the alkalinity index (AI)...
# 2                                  Monte Santo Suite.
# 3   and Hf in the multielement diagrams (Fig. 7, T...  The plot of both concordant and discordant ana...
# 4     lies vary from weak to well-pronounced troughs.  cies (n = 41) delineates a discordia line with...
# 5   The nepheline syenite, nepheline monzosyenite ...  1114.9 ± 9.5 Ma and a lower intercept of 265 ±...
# 6   syenite of the Estrela Massif (EM) present ano...  MSWD of 1.9 (Fig. 9A). Ten U-Pb measurements o...
# 7   of the Monte Santo Massif (MSM) syenites but w...  from the border facies are concordant and yiel...
# 8   bulk concentrations. The nepheline monzodiorit...  1108.1 ± 1.9 Ma, with\nan MSWD\nof\n0.062\n(Fi...
# 9   anomalies for Rb and K and negative anomalies ...  Mesoproterozoic ages are apparently regular re...
# 10  nepheline monzodiorite and nepheline monzosyen...                     CL textures within the grains.
# 11                          tive Nb and Ta anomalies.  In the central\nfacies, there are three differ...
# 12                                                     concordia plot of all the measurements (Fig. 9...
# 13                                                     sists of the older ages, which form a discordi...
# 14                            7. Zircon geochronology  cept of 1142 ± 24 Ma and a lower intercept of ...
# 15                                                     and 8C). The second population consists of a s...
# 16  We selected three samples from the Monte Santo...  of ca. 780 Ma. The last population is represen...
# 17  samples from the Estrela Massif for U-Pb geoch...  found in these rocks, which, regardless of the...
# 18  two samples are from the border facies (MS22 a...  points, yield concordia ages of 530.5 ± 4.3 Ma...
# 19  from the central facies (MS140), while in the ...  with MSWDs of 0.114 and 5, respectively (Figs....
# 20  kali feldspar syenite and a nepheline syenite ...  bly, the discordia line of the older ages does...
# 21  spectively). The results of\nthe U-Th-Pb isoto...                                      younger ages.
# 22  from the Monte Santo Massif and Estrela Massif...  Analyses show that the older ages are concentr...
# 23                                          pendix 2.  zircon grains with different CL textures and i...
# 24  Zircons from both facies of the MSM are genera...  younger ages are concentrated in the borders o...
# 25  cent to pink and brown and ranging in size fro...  pecially in the borders showing oscillatory zo...
# 26  border facies, some crystals preserve oscillat...                               intensity (Fig. 8B).
# 27  bands of alternating CL intensities, which is ...  The zircon crystals from the nepheline syenite...
# 28  zation, but are overprinted by patches and ove...  are brown,\ninclusion-rich,\nanhedral\ngrains,...
# 29  some crystals are featureless, presenting only...  2.12 mm. There is a distinction between the CL...
# 30  postmagmatic recrystallization features, such ...  and smaller grains. The larger grains are inte...
# 31  the presence of\ntransgressive zones of rehomo...  icate inclusions (feldspars and biotite), with...
# 32  light CL patches of varied shapes (some appear...  light CL spots, and thin borders with light lu...
# 33  others are inﬁlls, and still others are overgr...  smaller grains are more homogeneous than the l...
# 34  spread (Corfu et al., 2003).\nIn the central\n...  light to intermediate luminescence colors, oft...
# 35  darker, the oscillatory zoning is preserved in...  zoning but also presenting late to postmagmati...
# 36  growths or patches of light CL are less common...  volute zoning and patchy zoned replacements (F...
# 37  than in the border facies. In these crystals, ...  from the alkali feldspar syenite of the Estrel...
# 38  variably altered and/or recrystallized nuclei ...  well-developed crystal faces and range from 0....
# 39  rather than homogeneous light CL overgrowths (...  patterns show well-developed oscillatory zonin...
#                                                     0                                                  1
# 0   Fig. 5. Harker variation diagrams using additi...
# 1   Iwanuch (1991) data encompass both massifs and...
# 2   show the same small variation found in the mos...
# 3   tends to have dark luminescence colors, overgr...  the analyses yielded the older Mesoproterozoic...
# 4   latory zones of\nintermediate luminescence col...                                     other samples.
# 5   transgressed by light CL patchy zones or overg...
# 6   Four measurements on four different crystals f...                                      8. Discussion
# 7   enite yield a concordia age of 475.5 ± 4.3 Ma ...
# 8   (Fig. 10D), but the majority of the data fall ...          8.1. Mineral textures and crystallization
# 9   upper intercept of 1123 ± 48 Ma, a lower inter...
# 10  and an MSWD of 3.6 (Fig. 10C). The younger age...  Textural evidence suggests that the rocks of t...
# 11  nepheline syenite tend to concentrate in small...  comprising mainly granoblastic feldspars and f...
# 12  light luminescent crystals and within the ligh...  and present a more deformed texture than the E...
# 13                                   larger crystals.  which are coarser and present a well-preserved...
# 14  The analyses of the alkali feldspar syenite pl...  lar\nigneous\ntexture, with minor occurrences ...
# 15  diagram show concordant ages ranging from ca. ...                           heterogranular textures.
# 16  (Fig. 10A). The older ages within this range w...  The nepheline compositions of the two massifs ...
# 17  tion of the concordia age; fourteen analyses o...  nepheline compositions are more potassic and l...
# 18  yielded an age of 545.7 ± 3.4 with an MSWD of ...  compositions, which is\nreﬂected in the\nestim...
#                                                    0                                                  1
# 0                                                 10  E. Valentin et al. / Lithos 366–367 (2020) 105552
# 1  Fig. 6. Rare earth element diagrams for the Mo...
# 2                  from Viana and Battilani (2014a).
#                                                    0   ...     14
# 0                                             Table 2  ...
# 1   Whole-rock trace element analyses of the Monte...  ...
# 2                                           Rock Type  ...    AFS
# 3                                              Massif  ...    MSM
# 4                                          Sample no.  ...  MS398
# ..                                                ...  ...    ...
# 68                                                 Sm  ...   3.13
# 69                                                 Eu  ...   0.42
# 70                                                 Gd  ...    2.5
# 71                                                 Tb  ...   0.46
# 72                                                     ...
#
# [73 rows x 15 columns]
#                       0       1       2  ...       7        8       9
# 0                    12                  ...
# 1   Table 2 (continued)                  ...
# 2             Rock Type     NMD     NMS  ...      NS       NS     AFS
# 3                Massif      EM      EM  ...      EM       EM      EM
# 4            Sample no.  EVES13  EVES05  ...  EVES44   EVES50  EVES01
# 5                    Dy    3.88    0.96  ...    0.58     18.2    2.55
# 6                    Ho    0.84    0.22  ...    0.22     3.75    0.55
# 7                    Er    2.22    0.48  ...     0.7    11.25     1.5
# 8                    Tm    0.33    0.09  ...    0.13     1.78    0.24
# 9                    Yb    2.08    0.52  ...    1.31    12.95    2.16
# 10                   Lu    0.31    0.07  ...    0.26     2.06    0.37
# 11                 ∑REE  106.47   38.67  ...    50.6  1209.07   96.94
# 12               La/SmN    2.94    7.35  ...   14.26    10.23    3.47
# 13               Gd/LuN    1.52    1.71  ...    0.21     1.07    0.84
# 14               Eu/Eu*    1.01    0.40  ...    0.28     0.19    0.46
#
# [15 rows x 10 columns]
#                                                     0                                                  1
# 0                      Eu/Eu*\n1.01\n0.40\n0.20\n0.38                       0.22\n0.29\n0.28\n0.19\n0.46
# 1   temperatures, using the Hamilton and MacKenzie...  Eby et al. (1998) interpreted them as mineral ...
# 2   1961 thermometers. In the Estrela Massif, the ...  bulk magma composition.\nIn the Monte Santo Su...
# 3   on the order of ~1000 °C, are found in rocks w...  no clear correlation between the aluminum in m...
# 4   (nepheline monzodiorites), although the nephel...  rock\ncompositions, which\nsuggests\npostmagma...
# 5   tain nepheline crystals that record high tempe...                                      modiﬁcations.
# 6   highest temperature found in the syenites of t...  The\nclinopyroxene\ncompositions\nof\nboth mas...
# 7   In both massifs, the same types of rocks conta...  omphacite to aegirine-augite and aegirine, and...
# 8   that preserve both high-temperature and low-te...  enriched in the jadeite endmember (Jd of Morim...
# 9   ranging from as high as 1000 °C to less\nthan ...  Woolley et al. (1996) and Curtis and Gittins (...
# 10  reequilibrated crystals (Fig. 3A). Tilley (195...  through the metamorphism of nepheline-bearing ...
# 11  slowly cooled plutons or recrystallized intrus...  ous clinopyroxene chemistry shifts towards mor...
# 12  tions reequilibrate and concentrate along a li...  tions. Woolley et al. (1996) stated that the m...
# 13  and Morozewicz\ncompositions\n(Morozewicz-Bueg...  rocks generates aluminous aegirine-augite and ...
# 14  ﬁeld); however, this trend is not observed in ...  the metamorphism of agpaitic rocks generates a...
# 15  The diagram of Nachit et al. (2005) is used to...                                 jadeitic pyroxene.
# 16  primary, reequilibrated and neoformed biotites...  Although jadeitic and omphacitic pyroxenes are...
# 17  activity reequilibrates or promotes new crysta...  ered indicative of high-pressure metamorphism,...
# 18  and shifts their compositions to the base of t...  (1979)\ndescribed\nthese\nspecies\nas\ndevelop...
# 19  compositions in the MSS plot in the ﬁelds of p...  amphibolite-facies metamorphism in the agpaiti...
# 20  and neoformed grains (Fig. 11A). Only the comp...  Wine alkaline complex and inferred that both j...
# 21  and phlogopite samples from the EM, with high ...  crystallize at much lower pressures in a bulk ...
# 22  the primary ﬁeld, forming a linear array with ...                      that has low silica activity.
# 23  the\nreequilibrated\nﬁeld.\nSiderophyllite\nsa...  Fig. 12A displays the clinopyroxene compositio...
# 24  neoformed ﬁeld (radial texture biotite) or at ...  Suite in comparison with the primary igneous t...
# 25  neoformed and reequilibrated ﬁelds. In the MSM...  rocks of the Motzfeldt and South Qorôq intrusi...
# 26  plot within the primary ﬁeld. Interactions wit...  ince (Jones, 1980; Stephenson, 1972), Center I...
# 27  morphic ﬂuids could be responsible for these t...  (Mitchell and Platt, 1982) and selected rocks ...
# 28  TiO2; however, the biotite shapes and fabric w...  and Ross, 1990), as well as the metamorphic tr...
# 29  the presence of linear arrays in the Nachit et...  Elchuru\nalkaline\ncomplex\nin\nthe\nPrakasam ...
# 30  serving the Mg/Fe ratio within the same types ...  (Upadhyay et al., 2006) and North Nyasa Provin...
# 31  pected from magmatic reequilibration under coo...  1996). The clinopyroxenes of the Monte Santo S...
# 32                            than from metamorphism.  minous to represent an igneous trend and do no...
# 33  The compositional trends of the biotites from ...  trends of Elchuru and North Nyasa Province; ra...
# 34  are compared to those from other well-known al...  of these clinopyroxenes is intermediate betwee...
# 35  around the world in the Al-Mg-Fe2+ diagram (Fi...  phic compositions. In the Di-Hd-Ac diagram (Fi...
# 36  compositions of\nthe Oslo rift\nin Norway (And...  Suite pyroxenes depict trends similar to those...
# 37  1993), Igdlerﬁgsalik in South Greenland (Finch...  ince, representing a mixed character with both...
# 38  Canary Islands (Wolff, 1987), Chilwa Alkaline ...  served\nigneous\npyroxenes.\nCompositional\ntr...
# 39  (Woolley and Platt, 1988), and Magnet Cove in ...  enrichment alone do not necessarily characteri...
# 40  Ross, 1990), are used for comparison with pres...  tion trend for pyroxene, as can be found in ma...
# 41  plexes, while the North Nyasa Province in Mala...  plexes (Mitchell and Vladykin, 1996 and refere...
# 42  and the Elchuru alkaline complex in the Prakas...  observations, along with high aluminous compos...
# 43  (Upadhyay et al., 2006) are used for compariso...                                        indicators.
# 44                                         complexes.  The amphibole compositions of the MSS range fr...
# 45  Biotites with the highest amounts of TiO2 are ...  the nepheline monzodiorite to taramite in all\...
# 46  magmatic trends (red dashed line), while most ...  rocks (Fig. 3C). This variation results from C...
# 47  tions that plot in the reequilibrated and neof...  (Giret et al., 1980) with increasing different...
# 48  ﬁne individual trends enriched in aluminum (Fi...  note that the same species of amphibole is fou...
# 49  biotites are also observed in the trends of th...  in both massifs. The presence of zoning-free c...
#                                                    0   1
# 0  E. Valentin et al. / Lithos 366–367 (2020) 105552  13
# 1  Fig. 7. Multielement diagrams of the Monte San...
#                                                     0                                                  1
# 0   from the alkali feldspar syenite of the Estrel...
# 1   homogeneous, as well as their textural types, ...  nepheline, can be inferred from the positive a...
# 2   boles of both massifs represent recrystallized...  between major oxide elements. The evolution tr...
# 3   suggested that\nthe presence of\ntaramite amph...  from the Estrela Massif presents nepheline sye...
# 4   with jadeitic-rich clinopyroxenes\nis\na\nfeat...  feldspar syenite, while the Monte Santo Massif...
# 5                                        assemblages.                                      relationship.
# 6   From the mineral chemistry and textural inform...  The fractionation of maﬁc minerals and calcic ...
# 7   that the Monte Santo Suite contains well-prese...  ferred by the negative anomalies in Ti, Sr and...
# 8   as well as deformed and reequilibrated crystal...  agrams of the syenites (Fig. 7). The negative ...
# 9   subsolidus recrystallization occurred at P-T c...  syenites may\nbe\nindicative\nof\napatite\nand...
# 10  promote feldspar and nepheline grain boundary ...                                     fractionation.
# 11  perthite unmixing, indicating that at some poi...  In the REE diagrams (Fig. 6), different types ...
# 12  zation, plastic strain took place under high t...  parallel patterns, and the same type of rock c...
# 13  that the Monte Santo Suite represents magmas t...  variations in the bulk REE content (La varies ...
# 14  higher regional temperature and pressure condi...  could simply be the effect of extensive fracti...
# 15  rocks, which typically intrude low P-T regions...  be indicative that these rocks represent cumul...
# 16  that these magmas were intrusive under high P-...  trapped liquid, which could cause signiﬁcant v...
# 17  the mixed chemical character of most of the mi...                                   rock REE budget.
# 18  though the coexistence of aluminous clinopyrox...  In the multielement diagrams (Fig. 7), zirconi...
# 19  bole\nis\nconsidered\na metamorphic\nfeature\n...  play positive anomalies and have parallel tren...
# 20  clinopyroxene data do not ﬁt well in metamorph...  in the bulk concentration, where the highest c...
# 21                                                     ated with high HREE contents; this feature is ...
# 22         8.2. Monte Santo suite evolution processes  con accumulation and is commonly seen in petro...
# 23                                                     tantalum, similar to zirconium and hafnium, pr...
# 24  Harker diagrams (Fig. 5) show curved patterns ...  with large variations. In the zircon-enriched ...
# 25  tion between CaO, MgO and TiO2 and SiO2, and p...  ent, and the accumulation of pyrochlore could ...
# 26  tween Na2O and Al2O3 and SiO2 towards more dif...                     iations in Nb and Ta contents.
# 27  Curved patterns in variation diagrams indicate...  The Zr/Hf ratios are similar in both the most ...
# 28  with changing cumulate composition (Janousek e...  more differentiated rocks of the Monte Santo S...
# 29  sive fractionation of maﬁc minerals and possib...  along a straight line with a value of 43.1, wi...
# 30  erating differentiated magmas enriched in alka...  Zirconium and hafnium are elements with the sa...
#                                                    0   1
# 0  E. Valentin et al. / Lithos 366–367 (2020) 105552  15
# 1  Fig. 9. Concordia diagrams for the Monte Santo...
# 2  populations. D) Mesoproterozoic population of ...
#                                                     0                                                  1
# 0   Fig. 10. Concordia diagrams for the Estrela Ma...
# 1   the nepheline syenite. D) Concordia age of the...
# 2   similar ionic radii; therefore, it is expected...  The internal features and oscillatory zoning o...
# 3   stant in the same magmatic series (Linnen and ...  feldspar syenite from the Estrela Massif (Fig....
# 4   served in the Monte Santo Suite. The presence ...  545.7 ± 3.4 Ma represents the crystallization ...
# 5   tantalum anomalies in the multielement diagram...  younger ages obtained in the same zircon cryst...
# 6   studied rocks were derived from the mantle (Th...  trated in brighter CL overgrowth zones, sugges...
# 7   The negative Nb and Ta anomalies found in the ...  down to 510 Ma found in these samples may be e...
# 8   and nepheline monzosyenite are different from ...  involving zircon rejuvenation. An episodic pro...
# 9   nepheline syenites, which could be evidence of...  unlikely to explain such a spread along the co...
# 10  cesses involved in the evolution of the magmat...  riod of crystallization of 35 Ma is too long, ...
# 11  nately we do not have enough samples or data o...  pluton. Long-lived crystallization ages are re...
# 12  what could be these processes or if these rock...  of 8–10 Myr\nin nepheline syenite pegmatites\n...
# 13                             the Monte Santo Suite.  2015), 20 Myr in carbonatite-nepheline syenite...
# 14                                                     et al., 2016), and 7–8 Myr in large composite ...
# 15                                                     et al., 2007), all of which are much narrower ...
# 16  8.3. Age and tectonic signiﬁcance of the Monte...
# 17                                                     The 475.5 ± 4.3 Ma age for the nepheline syeni...
# 18                                                     obtained in both the borders of crystals with ...
# 19  As indicated by the geochemical data, the diff...
# 20                                                     smaller,\nlight\nCL\ncrystals\n(Fig.\n8C\nand\...
# 21  massifs of the Monte Santo Suite belong to the...
# 22                                                     Mesoproterozoic ages found in the same samples...
# 23  and probably had the same source. Furthermore,...
# 24                                                     line towards the Cambrian ages probably indica...
# 25  and mineral chemistry compositions suggest tha...
# 26                                                     ages represent an event responsible for Pb los...
# 27   iably deformed and recrystallized at some point.
#                                                    0                                                  1
# 0  Fig. 11. Monte Santo Suite biotite composition...
# 1                                                     where the A ﬁeld represents primary compositio...
# 2  compositions and the C ﬁeld represents neoform...
# 3  ternary diagram. The red arrow indicates the h...
# 4  Suite, which represent primary compositions. M...                                                  I
# 5  (Igdlerﬁgsalik), C (Chilwa Alkaline Province),...
# 6  while KC (Kasungu and Chipala, North Nyasa Pro...
# 7  phosed complexes. The symbols are the same as ...
#                                                     0                                                  1
# 0                                                      Fig. 12. Monte Santo Suite clinopyroxene compo...
# 1   ages are similar to those found in the Monte S...
# 2                                                      (1979) diagram for clinopyroxene compositions....
# 3   tals of this massif show many postmagmatic alt...
# 4                                                      ternary diagram. CCII (Coldwell Center II), SQ...
# 5     likely due to interactions with alkaline magma.  (Magnet Cove) are igneous complexes, while KC ...
# 6   Most of the data obtained from the Monte Santo...  Province) and E (Elchuru) are metamorphosed co...
# 7                                                                              those in previous ﬁgures.
# 8   populations of 1.1 Ga; however, the central fa...
# 9   Cambrian ages (530.5 ± 4.3 Ma and 493.3 ± 3.8 ...
# 10  tant geological meaning, despite the low stati...
# 11  these ages are very similar to both population...
# 12  tained in the Estrela Massif. Viana and Battil...  (diffusion, leaching and/or recrystallization)...
# 13  a similar population of ages for the Monte San...  morphism in previously metamict zircon crystal...
# 14  the crystals presented by these authors were r...  Mezger and Krogstad, 1997); therefore, these m...
# 15  crystals in the Estrela Massif based on size, ...  action of metamorphic, late magmatic, hydrothe...
# 16  The nepheline and alkali feldspar syenites of ...  (Geisler et al., 2003; Pidgeon, 1992; Vavra et...
# 17  similar geochemical anomalies, ratios and patt...  In the zircon population from the alkali\nfeld...
# 18  their mineral paragenesis also implies great o...  Estrela Massif, there is CL textural evidence ...
# 19  are foliated massifs intruding the contact bet...  younger than the magmatic crystallization, whi...
# 20  units. We believe that the geochemical and min...  of the isotopic system of the previous igneous...
# 21  are sufﬁcient to suggest that the crystallizat...  to postmagmatic process as pointed by Bao et a...
# 22  Massif is similar to that of the Estrela Massi...  chinese syenites. Additionally, all of the Mes...
# 23  and that the two massifs are cogenetic. Howeve...  in the two Monte Santo Suite massifs deﬁne dif...
# 24  of syenite evolution are a signiﬁcant differen...  lines that eventually reach a concordant\nlowe...
# 25  which could indicate different processes invol...  475 Ma) that according to Mezger and Krogstad,...
# 26                                       each massif.  have geological signiﬁcance. The younger Cambr...
# 27  The alkaline rocks of the Monte Santo Suite ar...  facies of the Monte Santo Massif are different...
# 28  concordant or near-concordant ages\nranging fr...  resent lower intercept ages; instead, they occ...
# 29  475 Ma. Many mechanisms have been proposed to ...  grains that are texturally different from the ...
# 30  juvenation processes, which involve isotopic d...  (Fig. 8B) and do not demonstrate a discordant ...
# 31  by solid-state recrystallization and precipita...  older ages. Additionally, the youngest Cambria...
# 32  metamorphism (Hoskin and Black, 2000) or ﬂuid-...  ple (493 Ma) is slightly discordant, while the...
#                                                     0  ...       8
# 0                                             Table 3  ...
# 1                                                      ...
# 2   respectively (Jacobsen and Wasserburg, 1980, 1...  ...
# 3                                              Sample  ...  T (Ga)
# 4                                               MS88A  ...   0.545
# 5                                              MS122A  ...   0.545
# 6                                               MS336  ...   0.545
# 7                                               MS140  ...   0.545
# 8                                               MS293  ...   0.545
# 9                                              MS316C  ...   0.545
# 10                                             EVES04  ...   0.545
# 11                                             EVES14  ...   0.545
# 12                                             EVES01  ...   0.545
#
# [13 rows x 9 columns]
#                                                     0                                                  1
# 0                          EVES01\nAFS\n3.101\n17.949          0.511949 (± 5)\n0.1044\n−7.0\n1.52\n0.545
# 1   (530 Ma) is concordant, suggesting that 530 Ma...  has been interpreted as a mega-suture active d...
# 2   tion age than 498 Ma and that 498 Ma deﬁnes a ...  gamation (Cordani et al., 2013) or as the resu...
# 3   The regional timing of metamorphism is not wel...  ing stages (Strieder and Suita, 1999); therefo...
# 4   there is evidence of regional U-Pb disturbance...  associated with this major structure or margin...
# 5   and 513 Ma\n(Alves\net\nal., 2019; Moura\net\n...  with the lineament could have been responsible...
# 6   Gaudette, 1993; Pinheiro, 2016), with cooling ...                          deformation of the suite.
# 7   ca. 505–489 Ma (Dias et al., 2017; Pinheiro, 2...  A similar process has been proposed for other ...
# 8   cult to assess whether metamorphism inﬂuenced ...  kaline intrusions in Africa (Attoh et al., 200...
# 9                      tion of the Monte Santo Suite.  and India (Biswal et al., 2007). In Cameroon, ...
# 10  Due to the lack of a wide background of local ...  trusions are considered to have been synkinema...
# 11  nological information and the lack of addition...  the Southwest Cameroon Shear Zone at 590 Ma an...
# 12  erals\nin\nthe\nparagenesis\n(e.g., monazite\n...  by magmatic to solid-state deformation structu...
# 13  investigated syenites, it is difﬁcult to estim...  where the deformation took place at depth (Emm...
# 14  Cambrian ages (498 and 475 Ma) and the age spr...  This situation is particularly different from ...
# 15  dated igneous zircon (EVES01) have geological ...  by Burke et al. (2003) for the generation of d...
# 16  The Mesoproterozoic crystals and a single 780 ...  and the signiﬁcance of these rocks as markers ...
# 17  the Monte Santo Massif can be interpreted, usi...  which can be exempliﬁed by the Tambani body of...
# 18  Miller et al. (2007), as inherited crystals fr...  Belt,\nsouthern\nMalawi,\nwhere\nthe\nintrusio...
# 19  from buried geological units in the emplacemen...  intracontinental rift at 730 Ma and was deform...
# 20  The metamaﬁc and ultramaﬁc rocks of the Aragua...  of the Panafrican orogeny at 522 Ma (Ashwal et...
# 21  750 to 810 Ma (Gorayeb et al., 2004; Paixão et...  There are examples in Africa and India of Edia...
# 22  source of contamination for the 780 Ma populat...  line magmatic rocks throughout Western Gondwan...
# 23  geological unit in the Araguaia Belt has an ag...  wana that were synkinematically emplaced and d...
# 24  age is found in provenance studies of the meta...         Monte Santo Suite represents another case.
# 25        the Estrondo Group (Pinheiro et al., 2011).
# 26  The shapes of the Mesoproterozoic zircon cryst...                         9. Summary and conclusions
# 27  irregular, well-developed crystal faces are ra...
# 28  features are relatively frequent in CL images....  The textural, petrographic and ﬁeld relations ...
# 29  that the Mesoproterozoic zircon crystals were ...  geochemical and isotopic data for the Monte Sa...
# 30                                 from their source.  the Estrela and Monte Santo massifs are cogene...
# 31  The Sm-Nd analyses (Table 3) yield TDM ages fo...     the Araguaia Belt at approximately 545–530 Ma.
# 32  Suite that range from 1.25 Ga to 1.54 Ga, whic...  This alkaline magmatism was mantle-sourced and...
# 33  errors, could point to the existence of a Meso...  intermediate to felsic, highly differentiated ...
# 34  mixture between older and younger sources. Add...  by fractional crystallization and involve chan...
# 35  values calculated at 545 Ma range from −10.1 t...  tions. The Monte Santo and Estrela massifs are...
# 36  either that this Mesoproterozoic source was de...  rocks that represent mixtures of cumulates and...
# 37  143Nd or\nthat\nthese magmas\nexperienced crus...  The textural evidence and mineral trends and c...
# 38  Foland et al. (1993) demonstrated that crustal...  that these massifs were, at some point, deform...
# 39  of making silica-undersaturated magmas reach o...  though there is signiﬁcant evidence of preserv...
# 40  the undersaturated rocks in the magmatic serie...                in nepheline, biotite and pyroxene.
# 41  evidence of contamination, which is a feature ...  The Monte Santo Suite represents Ediacaran-Cam...
# 42  Monte Santo Suite. Therefore, we believe that ...  magmatism in the Araguaia Belt that was synkin...
# 43  values apply to the source of these rocks, alt...  in an intra-orogenic extensional or\ntranstens...
# 44                necessary to conﬁrm this inference.  along shear zones related to the Transbrasilia...
# 45  The internal features observed in the studied ...  the Monte\nSanto\nSuite\nrepresents\nan\nexamp...
# 46  the regional background of the Araguaia Belt, ...  magmatism that occurred throughout Western Gon...
# 47  the alkaline rocks of the Monte Santo Suite cr...  synkinematically emplaced and deformed similar...
# 48        lution of the Brasiliano-Panafrican orogen.  scribed in Africa and in East Gondwana rocks f...
# 49  The Monte Santo Suite crops out near and along...  2007; Biswal et al., 2007; Emmanuel et al., 20...
# 50  parallel to the Transbrasiliano Lineament (Sch...  These magmas were generated from a Mesoprotero...
# 51  a 4000 km-long continental-scale discontinuity...  a mantle afﬁnity that was depleted in radiogen...

# %%
# tables_output is an empty list that will keep the actual tables that will be filtered

tables_output = []

# This time, my loop will iterate over all the table objects recognized by the read_pdf function. 
# All of which are kept in the tables2 variable. The term tables in tables2 is a generic term that 
# only exists inside the loop structure, it is a local variable.

for tables in tables2:
  
  # The first important thing to understand in this section of the code is the concept and notation 
  # of the table object. This object is a dataframe. A dataframe is similar to an Excel spreadsheet; 
  # it contains rows and columns. To navigate through these rows and columns, we use numbers. Since 
  # the local variable tables will take the value of each of the twenty-four table objects at each 
  # iteration, I will use the [column][row] notation to filter out what is an actual table.
  
  # Therefore I'm creating a logical condition based on the analysis of the table objects in tables2. 
  # Since this is a scientific paper, tables will have a legend (subtitle, I don't know), so my condition 
  # states that if the word 'Table' is contained in the first [0] or second [1] rows of the first [0] 
  # column (therefore, tables.df[0][0] or [0][1]) and if the table has more than three columns 
  # (tables.shape[1] > 2), they will be shown on the screen and added to the tables_output list. I chose 
  # tables.shape[1] because the .shape function returns a tuple containing the numbers of rows and columns, 
  # respectively (rows, columns), of each table; therefore, I'm referring to [1] because I'm only 
  # interested in the number of columns.   

  # Again, these parameters were all set considering my specific case. If you want to use this code in
  # your particular cases, the crucial part is understanding the difference between an actual table and 
  # gibberish in the last code cell. In this way, you can build your own filters and logical conditions 
  # based on mine or even expand them if you like.
  
  if ('Table' in tables.df[0][0] or 'Table' in tables.df[0][1]) and tables.shape[1] > 2:
    print(tables.df[0][0:3])
    print('')
    tables_output.append(tables)
# Out:
# 0                                              Table 1
# 1    Whole-rock major element analyses of the Monte...
# 2         eline syenite, AFS- Alkali feldspar syenite.
# Name: 0, dtype: object
#
# 0                                              Table 2
# 1    Whole-rock trace element analyses of the Monte...
# 2                                            Rock Type
# Name: 0, dtype: object
#
# 0                     12
# 1    Table 2 (continued)
# 2              Rock Type
# Name: 0, dtype: object
#
# 0                                              Table 3
# 1
# 2    respectively (Jacobsen and Wasserburg, 1980, 1...
# Name: 0, dtype: object

# %%
# This is the last part, where I iterated over the tables_output list to save each article's filtered 
# table as a .csv file. Supported formats are: .xlsx (to_excel), .html (to_html), .json (to_json) and 
# .db (to_sqlite). As you could see in the previous step, Table 2 was segmented into two different 
# pages in my article, and therefore, recognized as two different tables. The next text cells show 
# images of the .csv output. It is certainly not perfect, but it can be easily rearranged and organized 
# using the Pandas library in Python or any other programming language or simply copying and pasting 
# in Excel :). The output .csv file will be in the left sidebar, together with the uploaded .pdf files.

for tables in tables_output:
  tables.to_csv(f"Valentin_etal_2020-Table{tables_output.index(tables)+1}.csv")

# %% [markdown]
# ![Screen Shot 2021-03-11 at 21.26.57.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-03-11 at 21.27.18.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-03-11 at 21.27.27.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-03-11 at 21.27.50.png](data:image/png;base64,...)

# %% [markdown]
# #### Example 2: A thesis

# %% [markdown]
# * I used [Sciuba's 2020 PhD thesis](https://corpus.ulaval.ca/jspui/browse?type=author&order=ASC&rpp=20&authority=24f39a93-12d1-414c-847b-74b0ab5a0f2e) for testing.
#
# * I will focus on Sciuba's tourmaline database. Since it is a large database, I will not upload the .csv files on Github, but I will show you some example images.
#
# * This section will have less comments, since the logic of this code was explained before.

# %%
file_path2 = '/content/Sciuba_2020_PhD_Thesis_ULaval.pdf'

# %%
tables3 = camelot.read_pdf(file_path2, pages = "187-271", flavor='lattice')

# %%
tables3
# Out:
# <TableList n=0>

# %%
tables4 = camelot.read_pdf(file_path2, pages = "187-271", flavor='stream')
# Out:
# UserWarning: No tables found in table area 1 [stream.py:360]
# UserWarning: No tables found in table area 2 [stream.py:360]

# %%
tables4
# Out:
# <TableList n=125>

# %%
# I chose only the first five iterations because the database is too large.

for i in range(5):
  print(tables4[i].df)
# Out:
#                                                    0   ...        10
# 0   Appendix C-3. EPMA elements composition in tou...  ...
# 1                                            LOCALITY  ...  SiO2_pct
# 2                                           Hollinger  ...     36.80
# 3                                           Hollinger  ...     36.58
# 4                                           Hollinger  ...     36.90
# 5                                                Dome  ...     36.74
# 6                                                Dome  ...     36.27
# 7                                                Dome  ...     36.67
# 8                                                Dome  ...     36.46
# 9                                                Dome  ...     36.36
# 10                                               Dome  ...     35.92
# 11                                               Dome  ...     36.92
# 12                                               Dome  ...     36.32
# 13                                               Dome  ...     35.52
# 14                                               Dome  ...     37.90
# 15                                         Hoyle Pond  ...     37.16
# 16                                         Hoyle Pond  ...     36.50
# 17                                         Hoyle Pond  ...     36.68
# 18                                         Hoyle Pond  ...     35.73
# 19                                         Hoyle Pond  ...     35.80
# 20                                         Hoyle Pond  ...     38.22
# 21                                         Hoyle Pond  ...     36.73
# 22                                         Hoyle Pond  ...     36.33
# 23                                         Hoyle Pond  ...     36.21
# 24                                         Hoyle Pond  ...     36.36
# 25                                         Hoyle Pond  ...     36.06
# 26                                         Hoyle Pond  ...     36.51
# 27                                         Hoyle Pond  ...     35.89
# 28                                         Hoyle Pond  ...     35.98
# 29                                         Hoyle Pond  ...     36.13
# 30                                         Hoyle Pond  ...     36.51
# 31                                         Hoyle Pond  ...     36.14
# 32                                         Hoyle Pond  ...     36.08
# 33                                     Young Davidson  ...     34.80
# 34                                     Young Davidson  ...     35.04
# 35                                     Young Davidson  ...     34.91
# 36                                     Young Davidson  ...     35.01
# 37                                     Young Davidson  ...     34.55
# 38                                     Young Davidson  ...     35.05
# 39                                     Young Davidson  ...     35.47
# 40                                     Young Davidson  ...     34.87
# 41                                  Canadian Malartic  ...     36.20
# 42                                  Canadian Malartic  ...     35.94
# 43                                  Canadian Malartic  ...     36.20
# 44                                  Canadian Malartic  ...     35.56
# 45                                  Canadian Malartic  ...     36.48
# 46                                  Canadian Malartic  ...     35.97
# 47                                  Canadian Malartic  ...     35.49
# 48                                  Canadian Malartic  ...     35.37
# 49                                  Canadian Malartic  ...     34.94
#
# [50 rows x 11 columns]
#                                                    0   ...         10
# 0   Appendix C-3. EPMA elements composition in tou...  ...
# 1                                               TS_ID  ...  Al2O3_pct
# 2                                            HOLL-01B  ...      34.21
# 3                                            HOLL-01B  ...      33.90
# 4                                            HOLL-01B  ...      33.88
# 5                                            DOME-03B  ...      32.97
# 6                                            DOME-03B  ...      31.67
# 7                                            DOME-03B  ...      32.42
# 8                                            DOME-03B  ...      32.66
# 9                                            DOME-03B  ...      31.69
# 10                                           DOME-03B  ...      31.56
# 11                                           DOME-03B  ...      32.55
# 12                                           DOME-03B  ...      33.01
# 13                                           DOME-03B  ...      31.55
# 14                                           DOME-03B  ...      32.75
# 15                                           POND-05D  ...      33.72
# 16                                           POND-05D  ...      33.53
# 17                                           POND-05D  ...      33.47
# 18                                           POND-05D  ...      31.20
# 19                                           POND-05D  ...      32.15
# 20                                           POND-07A  ...      30.57
# 21                                           POND-07A  ...      34.08
# 22                                           POND-07A  ...      32.37
# 23                                           POND-09B  ...      31.37
# 24                                           POND-09B  ...      31.37
# 25                                           POND-09B  ...      31.23
# 26                                           POND-09B  ...      31.83
# 27                                           POND-09B  ...      30.61
# 28                                           POND-09B  ...      31.48
# 29                                           POND-09B  ...      31.10
# 30                                           POND-09B  ...      33.28
# 31                                           POND-09B  ...      31.20
# 32                                           POND-09B  ...      32.03
# 33                                           YOUN-15A  ...      26.69
# 34                                           YOUN-15A  ...      25.45
# 35                                           YOUN-15A  ...      26.46
# 36                                           YOUN-15A  ...      26.79
# 37                                           YOUN-15A  ...      24.52
# 38                                           YOUN-15A  ...      25.83
# 39                                           YOUN-15A  ...      27.12
# 40                                           YOUN-15A  ...      24.85
# 41                                            MALA-07  ...      31.70
# 42                                            MALA-07  ...      29.33
# 43                                            MALA-07  ...      31.06
# 44                                            MALA-07  ...      28.65
# 45                                            MALA-07  ...      31.40
# 46                                            MALA-07  ...      29.31
# 47                                            MALA-11  ...      29.42
# 48                                            MALA-11  ...      29.18
# 49                                            MALA-11  ...      26.82
#
# [50 rows x 11 columns]
#                            0              1   ...        10         11
# 0           Canadian Malartic        MALA-11  ...     35.20      28.88
# 1                    LOCALITY          TS_ID  ...  SiO2_pct  Al2O3_pct
# 2           Canadian Malartic        MALA-12  ...     34.92      28.12
# 3           Canadian Malartic        MALA-12  ...     35.94      30.33
# 4           Canadian Malartic        MALA-12  ...     35.10      27.04
# 5           Canadian Malartic        MALA-12  ...     35.77      29.88
# 6                     Roberto       ROBE-01A  ...     34.75      33.18
# 7                     Roberto       ROBE-01A  ...     36.16      32.21
# 8                     Roberto       ROBE-01A  ...     35.95      32.48
# 9                     Roberto       ROBE-01A  ...     35.75      32.57
# 10                    Roberto       ROBE-01A  ...     35.87      32.21
# 11                    Roberto       ROBE-01A  ...     35.96      32.90
# 12                    Roberto       ROBE-02A  ...     35.32      28.11
# 13                    Roberto       ROBE-02A  ...     35.58      28.65
# 14                    Roberto       ROBE-02A  ...     35.44      28.46
# 15                    Roberto       ROBE-02A  ...     35.48      28.48
# 16                    Roberto       ROBE-04A  ...     35.80      30.91
# 17                    Roberto       ROBE-04A  ...     35.28      30.00
# 18                    Roberto       ROBE-04A  ...     35.77      31.21
# 19                    Roberto       ROBE-04A  ...     35.86      31.24
# 20                    Roberto       ROBE-04A  ...     35.93      30.49
# 21                    Roberto       ROBE-04A  ...     35.58      30.55
# 22                    Roberto       ROBE-04A  ...     35.95      31.67
# 23                    Roberto       ROBE-04A  ...     35.92      30.04
# 24                    Roberto       ROBE-04A  ...     35.78      31.02
# 25                    Roberto        ROBE-05  ...     34.57      27.35
# 26                    Roberto        ROBE-05  ...     34.82      27.63
# 27                    Roberto        ROBE-05  ...     34.92      26.94
# 28                    Roberto        ROBE-05  ...     34.61      27.47
# 29                    Roberto        ROBE-06  ...     34.99      27.73
# 30                    Roberto        ROBE-06  ...     34.96      28.08
# 31                    Roberto        ROBE-06  ...     34.67      28.23
# 32                    Roberto        ROBE-06  ...     34.56      28.12
# 33                    Roberto        ROBE-06  ...     34.53      28.27
# 34                    Roberto        ROBE-06  ...     34.87      27.64
# 35                    Roberto        ROBE-06  ...     34.79      28.07
# 36                    Roberto        ROBE-06  ...     34.67      27.36
# 37                    Roberto        ROBE-06  ...     34.52      28.33
# 38  James Bay - Veine showing  LGS-98-136-50  ...     34.68      30.87
# 39  James Bay - Veine showing  LGS-98-136-50  ...     34.91      31.14
# 40  James Bay - Veine showing  LGS-98-136-50  ...     35.72      33.89
# 41  James Bay - Veine showing  LGS-98-136-50  ...     35.32      32.67
# 42  James Bay - Veine showing  LGS-98-136-50  ...     35.79      32.51
# 43  James Bay - Veine showing  LGS-98-136-50  ...     35.52      30.30
# 44  James Bay - Veine showing  LGS-98-136-50  ...     36.31      32.98
# 45  James Bay - Veine showing  LGS-98-136-50  ...     42.30      27.98
# 46     James Bay - As showing    15-RH-7166A  ...     36.15      34.54
# 47     James Bay - As showing    15-RH-7166A  ...     34.99      33.05
# 48     James Bay - As showing    15-RH-7166A  ...     35.63      32.28
# 49     James Bay - As showing    15-RH-7166A  ...     35.32      31.67
# 50     James Bay - As showing    15-RH-7166A  ...     34.99      32.83
#
# [51 rows x 12 columns]
#                               0               1   ...        10         11
# 0         James Bay - As showing     15-RH-7166A  ...     35.92      34.17
# 1                       LOCALITY           TS_ID  ...      SiO2      Al2O3
# 2         James Bay - As showing     15-RH-7166A  ...     35.37      32.50
# 3    James Bay - Wedding showing     15-RH-7194B  ...     35.18      31.62
# 4    James Bay - Wedding showing     15-RH-7194B  ...     35.23      30.53
# 5    James Bay - Wedding showing     15-RH-7194B  ...     35.91      33.58
# 6    James Bay - Wedding showing     15-RH-7194B  ...     35.64      33.97
# 7    James Bay - Wedding showing     15-RH-7194B  ...     35.97      32.40
# 8    James Bay - Wedding showing     15-RH-7194B  ...     35.70      33.26
# 9   James Bay - TR98-111 showing     15-RH-7175A  ...     35.95      32.39
# 10  James Bay - TR98-111 showing     15-RH-7175A  ...     35.53      30.82
# 11  James Bay - TR98-111 showing     15-RH-7175A  ...     35.98      31.41
# 12  James Bay - TR98-111 showing     15-RH-7175A  ...     35.26      30.61
# 13  James Bay - TR98-111 showing     15-RH-7175A  ...     35.37      30.28
# 14  James Bay - TR98-111 showing     15-RH-7175A  ...     38.31      28.84
# 15  James Bay - TR98-111 showing     15-RH-7175A  ...     35.26      30.91
# 16  James Bay - TR98-111 showing     15-RH-7175A  ...     35.97      32.37
# 17  James Bay - TR98-111 showing     15-RH-7175A  ...     35.49      31.33
# 18  James Bay - TR98-111 showing     15-RH-7175A  ...     35.89      31.26
# 19  James Bay - TR98-111 showing     15-RH-7175A  ...     35.65      30.73
# 20  James Bay - TR98-111 showing     15-RH-7175A  ...     35.53      29.72
# 21   James Bay - Wedding showing     15-RH-7194C  ...     35.75      32.81
# 22   James Bay - Wedding showing     15-RH-7194C  ...     35.55      32.98
# 23   James Bay - Wedding showing     15-RH-7194C  ...     35.87      32.99
# 24   James Bay - Wedding showing     15-RH-7194C  ...     35.34      32.25
# 25   James Bay - Wedding showing     15-RH-7194C  ...     36.22      33.67
# 26   James Bay - Wedding showing     15-RH-7194C  ...     35.14      33.03
# 27   James Bay - Wedding showing     15-RH-7194C  ...     35.82      33.49
# 28   James Bay - Wedding showing     15-RH-7194C  ...     35.45      32.49
# 29        James Bay - As showing     15-RH-7168A  ...     36.65      35.63
# 30        James Bay - As showing     15-RH-7168A  ...     36.51      33.82
# 31        James Bay - As showing     15-RH-7168A  ...     36.33      34.55
# 32        James Bay - As showing     15-RH-7168A  ...     36.73      36.11
# 33        James Bay - As showing     15-RH-7168A  ...     36.21      34.03
# 34        James Bay - As showing     15-RH-7168A  ...     36.12      33.11
# 35   James Bay - Marylou showing     15-RH-7203A  ...     36.17      32.48
# 36   James Bay - Marylou showing     15-RH-7203A  ...     35.18      30.54
# 37   James Bay - Marylou showing     15-RH-7203A  ...     36.35      32.12
# 38   James Bay - Marylou showing     15-RH-7203A  ...     35.53      30.38
# 39   James Bay - Marylou showing     15-RH-7203A  ...     35.89      30.97
# 40   James Bay - Marylou showing     15-RH-7203A  ...     35.14      29.16
# 41   James Bay - Marylou showing  LGS-96-07-57.5  ...     35.89      30.00
# 42   James Bay - Marylou showing  LGS-96-07-57.5  ...     35.62      29.19
# 43   James Bay - Marylou showing  LGS-96-07-57.5  ...     43.08      28.01
# 44   James Bay - Marylou showing  LGS-96-07-57.5  ...     35.95      29.40
# 45   James Bay - Marylou showing  LGS-96-07-57.5  ...     36.17      31.60
# 46                      LOCALITY           TS_ID  ...  SiO2_pct  Al2O3_pct
# 47   James Bay - Marylou showing  LGS-96-07-57.5  ...     35.14      28.56
# 48   James Bay - Marylou showing  LGS-96-07-57.5  ...     35.73      29.00
# 49   James Bay - Marylou showing  LGS-96-07-57.5  ...     35.43      27.73
#
# [50 rows x 12 columns]
#                              0               1   ...       9         10
# 0   James Bay - Marylou showing  LGS-96-07-57.5  ...     8.31     35.92
# 1   James Bay - Marylou showing    15-RH-7206AB  ...     8.44     36.05
# 2   James Bay - Marylou showing    15-RH-7206AB  ...     8.60     35.94
# 3   James Bay - Marylou showing    15-RH-7206AB  ...     8.92     36.03
# 4   James Bay - Marylou showing    15-RH-7206AB  ...     8.52     36.04
# 5   James Bay - Marylou showing    15-RH-7206AB  ...     8.59     36.43
# 6   James Bay - Marylou showing    15-RH-7206AB  ...     8.72     35.99
# 7   James Bay - Marylou showing    15-RH-7206AB  ...     8.52     36.42
# 8   James Bay - Marylou showing    15-RH-7206AB  ...     8.64     35.54
# 9   James Bay - Marylou showing    15-RH-7205AB  ...     7.34     35.22
# 10  James Bay - Marylou showing    15-RH-7205AB  ...     7.60     35.31
# 11  James Bay - Marylou showing    15-RH-7205AB  ...     7.90     35.28
# 12  James Bay - Marylou showing    15-RH-7205AB  ...     7.47     35.24
# 13  James Bay - Marylou showing    15-RH-7205AB  ...     7.59     35.32
# 14  James Bay - Marylou showing    15-RH-7205AB  ...     7.58     35.68
# 15  James Bay - Marylou showing    15-RH-7205AB  ...     7.63     35.65
# 16  James Bay - Orezone showing     15-RH-7213A  ...     6.63     35.38
# 17  James Bay - Orezone showing     15-RH-7213A  ...     7.42     35.43
# 18  James Bay - Orezone showing     15-RH-7213A  ...     6.61     35.34
# 19  James Bay - Orezone showing     15-RH-7213A  ...     7.13     35.21
# 20  James Bay - Orezone showing     15-RH-7213A  ...     6.63     35.94
# 21  James Bay - Orezone showing     15-RH-7213A  ...     7.36     35.33
# 22                    Excelsior         EXCE-01  ...     7.01     34.79
# 23                    Excelsior         EXCE-01  ...     6.98     35.08
# 24                    Excelsior         EXCE-01  ...     6.23     35.50
# 25                    Excelsior         EXCE-01  ...     5.51     34.45
# 26                    Excelsior         EXCE-01  ...     6.35     34.52
# 27                    Excelsior         EXCE-01  ...     6.66     34.41
# 28                    Excelsior         EXCE-01  ...     6.95     35.16
# 29                    Excelsior         EXCE-01  ...     6.81     34.87
# 30                    Excelsior         EXCE-01  ...     7.41     35.54
# 31                    Excelsior         EXCE-01  ...     6.55     34.42
# 32         Royal Hill - Rosebel      RHD-38029B  ...     6.72     36.09
# 33         Royal Hill - Rosebel      RHD-38029B  ...     6.06     35.25
# 34         Royal Hill - Rosebel      RHD-38029B  ...     6.84     35.92
# 35         Royal Hill - Rosebel      RHD-38029B  ...     6.59     35.85
# 36         Royal Hill - Rosebel      RHD-38029B  ...     6.52     35.52
# 37         Royal Hill - Rosebel      RHD-38029B  ...     6.76     35.25
# 38         Royal Hill - Rosebel      RHD-467-38  ...     4.82     35.90
# 39                     LOCALITY           TS_ID  ...  MgO_pct  SiO2_pct
# 40         Royal Hill - Rosebel      RHD-467-38  ...     5.19     35.42
# 41         Royal Hill - Rosebel      RHD-467-38  ...     4.82     35.98
# 42         Royal Hill - Rosebel      RHD-467-38  ...     5.26     35.34
# 43         Royal Hill - Rosebel      RHD-467-38  ...     4.62     36.09
# 44         Royal Hill - Rosebel      RHD-467-38  ...     5.77     35.48
# 45         Royal Hill - Rosebel      RHD-467-38  ...     4.68     36.11
# 46         Royal Hill - Rosebel      RHD-467-38  ...     5.10     35.39
# 47         Royal Hill - Rosebel      RHD-447-57  ...     5.22     35.79
# 48         Royal Hill - Rosebel      RHD-447-57  ...     1.67     35.42
# 49         Royal Hill - Rosebel      RHD-447-57  ...     5.40     35.87
# 50         Royal Hill - Rosebel      RHD-447-57  ...     4.82     35.51
#
# [51 rows x 11 columns]

# %%
# By choosing tables4[-i], I can see the last 5 elements of tables4, but in reverse order,
# so the first to appear on the screen is actually the last element.

for i in range(1, 5):
  print(tables4[(-i)].df)
# Out:
#                     0          1         2
# 0          ANALYSE_ID  Th232_ppm  U238_ppm
# 1   LRTO-04-L3-18.775       0.01      0.01
# 2   LRTO-04-L3-14.764       0.00      0.03
# 3   LRTO-04-L4-42.736       0.00      0.07
# 4   LRTO-04-L4-12.121       0.00      0.00
# 5   LRTO-04-L5-20.386       0.01      0.01
# 6   LRTO-04-L6-26.773       0.06      0.29
# 7   LRTO-04-L6-25.985       0.01      0.05
# 8   LRTO-04-L7-17.455       0.01      0.00
# 9   LRTO-04-L7-22.311       0.00      0.01
# 10  LRTO-04-L8-47.115       0.00      0.00
# 11  LRTO-04-L9-59.255       0.02      0.16
#                      0          1         2
# 0           ANALYSE_ID  Th232_ppm  U238_ppm
# 1    NEVA-01-L4-27.913       0.37      0.02
# 2    NEVA-01-L4-10.492       0.05      0.01
# 3    NEVA-01-L5-7.9105       0.47      0.08
# 4    NEVA-01-L5-19.984       0.96      0.23
# 5    NEVA-01-L5-10.955       1.05      0.20
# 6    NEVA-01-L6-19.339       0.09      0.02
# 7    NEVA-01-L7-11.741       0.24      0.04
# 8    NEVA-01-L7-10.003       0.08      0.02
# 9    NEVA-01-L8-24.674       0.03      0.01
# 10   NEVA-01-L9-6.1618       9.30     16.70
# 11   NEVA-01-L9-5.4124       1.63      2.21
# 12  ROBE-06-L1.-51.327       0.00      0.02
# 13  ROBE-06-L1.-51.685       0.01      0.14
# 14  ROBE-06-L1.-35.589       0.05      2.76
# 15   ROBE-06-L2.-21.64       0.02      1.73
# 16  ROBE-06-L2.-67.065       0.02      0.89
# 17   ROBE-06-L3.-18.42       0.00      0.01
# 18  ROBE-06-L3.-38.272       7.10     82.30
# 19  ROBE-06-L3.-45.425       0.31      9.77
# 20  ROBE-06-L3.-15.022       0.06     11.60
# 21  ROBE-06-L4.-20.745       0.00      0.03
# 22  ROBE-06-L4.-29.846       0.00      0.00
# 23   ROBE-06-L4.-12.87       0.04      3.83
# 24  ROBE-06-L4.-51.478       0.00      0.11
# 25   ROBE-06-L5.-29.33       0.00      0.01
# 26  ROBE-06-L5.-67.601       0.00      0.01
# 27  ROBE-06-L5.-31.297       0.15      6.70
# 28  ROBE-06-L6.-42.168       0.01      2.74
# 29  ROBE-06-L6.-42.385       0.00      0.07
# 30  ROBE-06-L6.-31.297       0.19      3.14
# 31   ROBE-06-L6.-24.68       0.12      3.37
# 32   LRTO-02-L1-32.042        <DL      0.00
# 33   LRTO-02-L2-20.635        <DL      0.00
# 34   LRTO-02-L3-24.991       0.00      0.01
# 35   LRTO-02-L3-18.147       0.00      0.00
# 36   LRTO-02-L4-30.724       0.00      0.00
# 37   LRTO-02-L4-21.204       0.00      0.00
# 38   LRTO-02-L5-24.576       0.01      0.04
# 39   LRTO-02-L6-13.066       0.00      0.00
# 40   LRTO-02-L6-12.962       0.00      0.00
# 41    LRTO-02-L6-12.34       0.00      0.00
# 42   LRTO-02-L7-62.904       0.00      0.00
# 43   LRTO-02-L8-35.464       0.00      0.01
# 44   LRTO-02-L8-21.258       0.16      0.60
# 45   LRTO-02-L9-16.902       0.09      0.29
# 46    LRTO-02-L9-21.05       0.01      0.03
# 47   LRTO-02-L9-21.983       0.00      0.02
# 48    LRTO-04-L1-12.03        <DL       <DL
# 49    LRTO-04-L3-12.03       0.00      0.01
#                       0          1         2
# 0            ANALYSE_ID  Th232_ppm  U238_ppm
# 1    BIGB-01A-L2-26.105       0.01      0.01
# 2    BIGB-01A-L2-34.182       0.05      0.12
# 3     BIGB-01A-L3-48.07       0.00       <DL
# 4    BIGB-01A-L4-21.299       0.00      0.00
# 5    BIGB-01A-L5-5.4713       0.00      0.00
# 6     BIGB-01A-L5-36.15       0.00      0.00
# 7    BIGB-01A-P6-17.208       4.60      4.80
# 8    BIGB-01A-P7-25.207       0.01      0.00
# 9    BIGB-01A-P8-7.1323       0.00       <DL
# 10   BIGB-01A-P9-28.334       0.00      0.00
# 11   STIV-09a-L1-37.588        <DL      0.00
# 12    STIV-09a-L2-34.72       0.00      0.00
# 13   STIV-09a-L3-8.4821        <DL       <DL
# 14   STIV-09a-L3-12.551        <DL       <DL
# 15   STIV-09a-L4-49.403       0.00      0.00
# 16   STIV-09B-L2-36.022       0.00      0.00
# 17   STIV-09B-L2-16.321       0.00      0.01
# 18   STIV-09B-L3-18.769        <DL      0.00
# 19   STIV-09B-L3-35.439       0.00      0.00
# 20   STIV-09B-L4-10.958       0.00      0.00
# 21    STIV-09B-L4-17.37       0.00      0.00
# 22   STIV-09B-L5-22.499       0.00      0.00
# 23   STIV-09B-L5-20.984       0.00      0.00
# 24    STIV-09B-L5-21.45        <DL      0.00
# 25   STIV-09B-L6-14.222       0.00      0.00
# 26   STIV-09B-L6-13.756       0.00      0.00
# 27   STIV-09B-L6-11.191        <DL       <DL
# 28    STIV-09B-L7-13.64       0.00      0.00
# 29    STIV-09B-L7-12.59        <DL      0.00
# 30   STIV-09B-L8-10.254       0.00      0.01
# 31   STIV-09B-L8-21.658       0.00      0.00
# 32   STIV-09B-L8-18.938       0.00      0.02
# 33   STIV-09B-L8-12.137       0.00      0.01
# 34   STIV-09B-L9-13.811       0.00      0.00
# 35   STIV-09B-L9-27.936       0.00      0.00
# 36  STIV-09B-L10-16.741       0.01      0.01
# 37  STIV-09B-L11-43.107       0.00       <DL
# 38   STIV-09B-L11-40.91       0.00       <DL
# 39  STIV-09B-L12-14.439       0.00      0.00
# 40   STIV-09B-L12-21.24       0.00      0.00
# 41  STIV-09B-L13-33.272       0.00      0.00
# 42  STIV-09B-L13-29.505        <DL      0.00
# 43  STIV-09B-L13-14.753        <DL      0.00
# 44    NEVA-01-L1-21.317       0.01      0.00
# 45    NEVA-01-L1-18.569       0.52      0.02
# 46    NEVA-01-L1-13.323       0.85      0.02
# 47    NEVA-01-L2-17.243       0.22      0.01
# 48    NEVA-01-L2-16.004       0.44      0.02
# 49    NEVA-01-L3-30.104       0.23      0.02
#                       0          1         2
# 0            ANALYSE_ID  Th232_ppm  U238_ppm
# 1    BIGB-01A-L2-26.105       0.01      0.01
# 2    BIGB-01A-L2-34.182       0.05      0.12
# 3     BIGB-01A-L3-48.07       0.00       <DL
# 4    BIGB-01A-L4-21.299       0.00      0.00
# 5    BIGB-01A-L5-5.4713       0.00      0.00
# 6     BIGB-01A-L5-36.15       0.00      0.00
# 7    BIGB-01A-P6-17.208       4.60      4.80
# 8    BIGB-01A-P7-25.207       0.01      0.00
# 9    BIGB-01A-P8-7.1323       0.00       <DL
# 10   BIGB-01A-P9-28.334       0.00      0.00
# 11   STIV-09a-L1-37.588        <DL      0.00
# 12    STIV-09a-L2-34.72       0.00      0.00
# 13   STIV-09a-L3-8.4821        <DL       <DL
# 14   STIV-09a-L3-12.551        <DL       <DL
# 15   STIV-09a-L4-49.403       0.00      0.00
# 16   STIV-09B-L2-36.022       0.00      0.00
# 17   STIV-09B-L2-16.321       0.00      0.01
# 18   STIV-09B-L3-18.769        <DL      0.00
# 19   STIV-09B-L3-35.439       0.00      0.00
# 20   STIV-09B-L4-10.958       0.00      0.00
# 21    STIV-09B-L4-17.37       0.00      0.00
# 22   STIV-09B-L5-22.499       0.00      0.00
# 23   STIV-09B-L5-20.984       0.00      0.00
# 24    STIV-09B-L5-21.45        <DL      0.00
# 25   STIV-09B-L6-14.222       0.00      0.00
# 26   STIV-09B-L6-13.756       0.00      0.00
# 27   STIV-09B-L6-11.191        <DL       <DL
# 28    STIV-09B-L7-13.64       0.00      0.00
# 29    STIV-09B-L7-12.59        <DL      0.00
# 30   STIV-09B-L8-10.254       0.00      0.01
# 31   STIV-09B-L8-21.658       0.00      0.00
# 32   STIV-09B-L8-18.938       0.00      0.02
# 33   STIV-09B-L8-12.137       0.00      0.01
# 34   STIV-09B-L9-13.811       0.00      0.00
# 35   STIV-09B-L9-27.936       0.00      0.00
# 36  STIV-09B-L10-16.741       0.01      0.01
# 37  STIV-09B-L11-43.107       0.00       <DL
# 38   STIV-09B-L11-40.91       0.00       <DL
# 39  STIV-09B-L12-14.439       0.00      0.00
# 40   STIV-09B-L12-21.24       0.00      0.00
# 41  STIV-09B-L13-33.272       0.00      0.00
# 42  STIV-09B-L13-29.505        <DL      0.00
# 43  STIV-09B-L13-14.753        <DL      0.00
# 44    NEVA-01-L1-21.317       0.01      0.00
# 45    NEVA-01-L1-18.569       0.52      0.02
# 46    NEVA-01-L1-13.323       0.85      0.02
# 47    NEVA-01-L2-17.243       0.22      0.01
# 48    NEVA-01-L2-16.004       0.44      0.02
# 49    NEVA-01-L3-30.104       0.23      0.02

# %%
# Both previous loops are to check if the selected pages in the read_pdf function are accurate. 
# The tables4 variable is precisely what I wanted to extract from the pdf file, so we can already 
# jump to the last step on the first example.

tables_output2 = []

for tables in tables4:
    tables_output2.append(tables)

for tables in tables_output2:
  tables.to_csv(f"Sciuba_2020-Table{tables_output2.index(tables)+1}.csv")

# %% [markdown]
# ![Screen Shot 2021-03-11 at 22.09.48.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-03-11 at 22.10.10.png](data:image/png;base64,...)

# %% [markdown]
# *   The tables are segmented, but they can be easily joined together using Pandas in Python.
# *   Hope you find this code useful. If you have any questions, please don't hesitate to contact me at: eduardo.valentin-dos-santos.1@ulaval.ca
